y_400 = np.array ([117,239,376,525,681,841,1002,1165,1328,1501,1666,1836,2007,2179,2348,2522,2692,2868,3040,3221,3401,3568,3747,3929,4109,4278,4466,4637,4826,4993,5173,5354,5529,5723,5892,6080,6257,6437,6613,6782,6963,7144,7341,7508,7688,7880,8051,8242,8436,8608,8780,8960,9161,9337,9494,9700,9869,10058,10249,10426,10610,10803,10985,11175,11352,11541,11729,12052,12215,12388,12602,12779,12955,13152,13312,13503,13678,13898,14070,14226,14421,14615,14807,14989,15188,15398,15583,15749,15956,16273,16408,16592,16775,16962,17605,18172,18114,18333,19081,18069])
y_1000 = np.array ([269,547,825,1106,1385,1666,1943,2222,2508,2792,3076,3367,3687,3999,4315,4634,4971,5310,5659,6013,6362,6712,7067,7419,7780,8138,8496,8881,9236,9608,9992,10349,10737,11120,11510,11880,12284,12653,13026,13381,13790,14207,14856,15472,15581,16690,17491,17518,17830,18845,19116,18623,19004,19174,19583,20003,20409,20796,21218,21618,22251,22525,23040,23602,23776,24140,24501,24901,25312,26601,26947,26836,26740,27842,28589,28646,28699,29137,29839,30107,30566,30891,31107,31513,31920,32445,34065,35095,33890,34171,34850,37461,35606,36408,36344,37276,37694,37869,38311,39290])

xnew = np.linspace (x. min (), x. max (), 200) 

spl = make_interp_spline (x, y_5, k = 3)
y_smooth_5 = spl (xnew)

spl = make_interp_spline (x, y_10, k = 3)
y_smooth_10 = spl (xnew)

spl = make_interp_spline (x, y_25, k = 3)
y_smooth_25 = spl (xnew)

spl = make_interp_spline (x, y_50, k = 3)
y_smooth_50 = spl (xnew)

spl = make_interp_spline (x, y_100, k = 3)
y_smooth_100 = spl (xnew)

spl = make_interp_spline (x, y_200, k = 3)
y_smooth_200 = spl (xnew)

spl = make_interp_spline (x, y_300, k = 3)
y_smooth_300 = spl (xnew)

spl = make_interp_spline (x, y_400, k = 3)
y_smooth_400 = spl (xnew)

spl = make_interp_spline (x, y_1000, k = 3)
y_smooth_1000 = spl (xnew)


plt.plot (xnew, y_smooth_5,  'b',
          xnew, y_smooth_10, 'r', 
          xnew, y_smooth_25, 'g',
          xnew, y_smooth_50, 'm',
          xnew, y_smooth_100, 'y',
          xnew, y_smooth_200, 'darkgreen',
          xnew, y_smooth_300, 'c',
          xnew, y_smooth_400, 'aquamarine',
          xnew, y_smooth_1000, 'orange',
          xnew, y_smooth_binary, 'k')

plt.show() 

plt.axis([100000,2000000,0,1000])
plt.title('K heap sort, low values')
plt.xlabel('size')
plt.ylabel('time, ms')
plt.plot (xnew, y_smooth_5,  'b',
          xnew, y_smooth_10, 'r', 
          xnew, y_smooth_25, 'g',
          xnew, y_smooth_50, 'm',
          xnew, y_smooth_100, 'y',
          xnew, y_smooth_200, 'darkgreen',
          xnew, y_smooth_300, 'c',
          xnew, y_smooth_400, 'aquamarine',
          xnew, y_smooth_1000, 'orange',
          xnew, y_smooth_binary, 'k')
plt.show()
